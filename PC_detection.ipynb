# %%
# from google.colab import drive
# drive.mount("/content/gdrive")

# !google-drive-ocamlfuse -cc
# clear the cache and refresh the files. 
# Every time you change a file in drive folder, you should call this command and the mounted drive would refresh with the changes.
# Out:
# Mounted at /content/gdrive

# %%
import os

# %%
PATH = 'drive/MyDrive/Colab/PC_detection'
os.chdir(PATH)

# %%
# !unzip  train.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Patient_70/Set_2/Slice_156_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_157_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_158_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_159_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_15_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_160_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_161_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_162_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_163_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_164_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_165_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_166_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_167_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_168_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_169_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_16_CT_Image.png
#   inflating: Patient_70/Set_2/Slice_170_CT_Image.png
# ...

# %%
ls -v
# Out:
# Patient_1/   Patient_46/   Patient_109/  Patient_149/  Patient_206/
# Patient_2/   Patient_50/   Patient_112/  Patient_150/  Patient_207/
# Patient_3/   Patient_52/   Patient_113/  Patient_153/  Patient_208/
# Patient_4/   Patient_57/   Patient_114/  Patient_156/  Patient_209/
# Patient_6/   Patient_62/   Patient_115/  Patient_158/  Patient_211/
# Patient_7/   Patient_63/   Patient_116/  Patient_160/  Patient_212/
# Patient_9/   Patient_66/   Patient_117/  Patient_163/  Patient_215/
# Patient_10/  Patient_67/   Patient_119/  Patient_165/  Patient_216/
# Patient_16/  Patient_70/   Patient_121/  Patient_172/  Patient_217/
# Patient_17/  Patient_72/   Patient_122/  Patient_174/  Patient_219/
# Patient_19/  Patient_76/   Patient_125/  Patient_175/  Patient_220/
# Patient_21/  Patient_81/   Patient_131/  Patient_176/  Patient_221/
# Patient_22/  Patient_82/   Patient_133/  Patient_178/  Patient_225/
# Patient_26/  Patient_84/   Patient_134/  Patient_182/  Patient_229/
# ...

# %%
# !ls -v
# Out:
# Patient_8   Patient_53	Patient_85   Patient_129  Patient_162  Patient_199
# Patient_15  Patient_55	Patient_91   Patient_130  Patient_168  Patient_210
# Patient_18  Patient_60	Patient_92   Patient_132  Patient_169  Patient_213
# Patient_20  Patient_61	Patient_94   Patient_138  Patient_179  Patient_218
# Patient_24  Patient_64	Patient_100  Patient_144  Patient_187  Patient_222
# Patient_35  Patient_71	Patient_105  Patient_151  Patient_190  Patient_223
# Patient_37  Patient_73	Patient_108  Patient_152  Patient_192  Patient_227
# Patient_47  Patient_75	Patient_118  Patient_157  Patient_193  Patient_228
# Patient_49  Patient_77	Patient_123  Patient_159  Patient_196  Patient_237
# Patient_51  Patient_83	Patient_127  Patient_161  Patient_197  Patient_239

# %%
# !unzip train.zip -d train_2/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train_2/Patient_70/Set_2/Slice_156_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_157_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_158_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_159_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_15_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_160_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_161_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_162_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_163_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_164_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_165_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_166_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_167_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_168_CT_Image.png
#   inflating: train_2/Patient_70/Set_2/Slice_169_CT_Image.png
# ...

# %%
cd train_2
# Out:
# /content/drive/My Drive/Colab/PC_detection/train_2

# %%
# !ls -v
# Out:
# Patient_1   Patient_41	Patient_90   Patient_133  Patient_172  Patient_211
# Patient_2   Patient_42	Patient_95   Patient_134  Patient_174  Patient_212
# Patient_3   Patient_43	Patient_98   Patient_137  Patient_175  Patient_215
# Patient_4   Patient_45	Patient_101  Patient_139  Patient_176  Patient_216
# Patient_6   Patient_46	Patient_103  Patient_140  Patient_178  Patient_217
# Patient_7   Patient_50	Patient_104  Patient_141  Patient_182  Patient_219
# Patient_9   Patient_52	Patient_106  Patient_142  Patient_183  Patient_220
# Patient_10  Patient_57	Patient_107  Patient_143  Patient_185  Patient_221
# Patient_16  Patient_62	Patient_109  Patient_145  Patient_188  Patient_225
# Patient_17  Patient_63	Patient_112  Patient_146  Patient_189  Patient_229
# Patient_19  Patient_66	Patient_113  Patient_147  Patient_194  Patient_230
# Patient_21  Patient_67	Patient_114  Patient_148  Patient_195  Patient_231
# Patient_22  Patient_70	Patient_115  Patient_149  Patient_198  Patient_232
# ...

# %%
# !mv -i train_2 train

# %%
ls
# Out:
# test/  test.zip  train/  train.zip

# %%
cd -
# Out:
# /content/drive/My Drive/Colab/PC_detection
